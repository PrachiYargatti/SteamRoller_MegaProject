# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.10.0+cu128
# True

# %%
# !f5-tts_infer-cli --help
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# usage: python3 infer-cli.py [-h] [-c CONFIG] [-m MODEL] [-mc MODEL_CFG]
#                             [-p CKPT_FILE] [-v VOCAB_FILE] [-r REF_AUDIO]
#                             [-s REF_TEXT] [-t GEN_TEXT] [-f GEN_FILE]
#                             [-o OUTPUT_DIR] [-w OUTPUT_FILE] [--save_chunk]
# ...

# %%
# !git clone https://github.com/SWivid/F5-TTS.git
# Out:
# Cloning into 'F5-TTS'...
# remote: Enumerating objects: 4036, done.
# remote: Total 4036 (delta 0), reused 0 (delta 0), pack-reused 4036 (from 1)
# Receiving objects: 100% (4036/4036), 2.35 MiB | 13.23 MiB/s, done.
# Resolving deltas: 100% (2474/2474), done.

# %%
# %cd /kaggle/working/F5-TTS
# Out:
# /kaggle/working/F5-TTS

# %%
# !pip install -e .
# Out:
# Obtaining file:///kaggle/working/F5-TTS
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 49.8 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 MB 46.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 61.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.5/155.5 kB 14.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 kB 6.4 MB/s eta 0:00:00
# ...

# %%
# !pwd
# Out:
# /kaggle/working/F5-TTS

# %%
# !ls
# Out:
# ckpts  data  Dockerfile  LICENSE  pyproject.toml  README.md  ruff.toml	src

# %%
# !ls src/f5_tts/infer
# Out:
# examples      infer_gradio.py  SHARED.md       utils_infer.py
# infer_cli.py  README.md        speech_edit.py

# %%
# !pip install -e .
# Out:
# Obtaining file:///kaggle/working/F5-TTS
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for f5-tts (pyproject.toml) ... done
#   Created wheel for f5-tts: filename=f5_tts-1.1.22-0.editable-py3-none-any.whl size=7124 sha256=9ce0b4ca9b23314781f6bb265d0f8455f90debf5fe3bb369ecd06727e549ee44
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1rh5ru14/wheels/5d/dd/a0/fcf55da116bdd7fda07485dd42e64773a4e2a43cf1f19c0e71
# Successfully built f5-tts
# ...
#   Attempting uninstall: f5-tts
#     Found existing installation: f5-tts 1.1.22
#     Uninstalling f5-tts-1.1.22:

# %%
# !python -m f5_tts.infer.infer_cli \
  --model F5TTS_Base \
  --ref_audio "/kaggle/input/stutter/sattu_patil.wav.wav" \
  --ref_text "Exact text spoken in your audio sample" \
  --gen_text "This is the new text you want F5-TTS to generate." \
  --output_dir "/kaggle/working/output" \
  --output_file "generated_speech.wav"
# Out:
# /usr/bin/python3: Error while finding module specification for 'f5_tts.infer.infer_cli' (ModuleNotFoundError: No module named 'f5_tts')

# %%
# %cd /kaggle/working/F5-TTS
# !pip install -e .
# Out:
# [Errno 2] No such file or directory: '/kaggle/working/F5-TTS'
# /kaggle/working
# Obtaining file:///kaggle/working
# ERROR: file:///kaggle/working does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
# 1. Clone the repository and install F5-TTS
# !git clone https://github.com/SWivid/F5-TTS.git /kaggle/working/F5-TTS
# %cd /kaggle/working/F5-TTS
# !pip install -e .

# 2. Run the inference command using python -m from inside the directory
# !python infer/infer_cli.py \
  --model F5TTS_Base \
  --ref_audio "/kaggle/input/stutter/sattu_patil.wav.wav" \
  --ref_text "Type the transcript of sattu_patil audio here" \
  --gen_text "Type the new text you want to generate here" \
  --output_dir "/kaggle/working/output" \
  --output_file "generated_speech.wav"
# Out:
# Cloning into '/kaggle/working/F5-TTS'...
# remote: Enumerating objects: 4036, done.
# remote: Total 4036 (delta 0), reused 0 (delta 0), pack-reused 4036 (from 1)
# Receiving objects: 100% (4036/4036), 2.35 MiB | 30.86 MiB/s, done.
# Resolving deltas: 100% (2474/2474), done.
# /kaggle/working/F5-TTS
# Obtaining file:///kaggle/working/F5-TTS
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 103.1 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 MB 48.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 62.5 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !f5-tts_infer-cli \
  --model F5TTS_Base \
  --ref_audio "/kaggle/input/stutter/sattu_patil.wav.wav" \
  --ref_text "Type the exact transcript of sattu_patil audio here" \
  --gen_text "Type the new text you want to generate here" \
  --output_dir "/kaggle/working/output" \
  --output_file "generated_speech.wav"
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# Download Vocos from huggingface charactr/vocos-mel-24khz
# config.yaml: 100%|█████████████████████████████| 461/461 [00:00<00:00, 2.26MB/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# ...

# %%
# !f5-tts_infer-cli \
  --model F5TTS_Base \
  --ref_audio "/kaggle/input/datasets/sanikasathe20/stutter/sattu_patil.wav.wav" \
  --ref_text "Hello, this is a sample reference text for voice cloning." \
  --gen_text "This is a generated test sentence using the F5 TTS voice cloning model." \
  --output_dir "/kaggle/working/output" \
  --output_file "generated_speech.wav"
# Out:
# Download Vocos from huggingface charactr/vocos-mel-24khz
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Using F5TTS_Base...
#
# vocab :  /kaggle/working/F5-TTS/src/f5_tts/infer/examples/vocab.txt
# token :  custom
# model :  /root/.cache/huggingface/hub/models--SWivid--F5-TTS/snapshots/84e5a410d9cead4de2f847e7c9369a6440bdfaca/F5TTS_Base/model_1200000.safetensors
#
# Voice: main
# ref_audio  /kaggle/input/datasets/sanikasathe20/stutter/sattu_patil.wav.wav
# Converting audio...
# Audio is over 12s, clipping short. (3)
# Using custom reference text...
#
# ref_text   Hello, this is a sample reference text for voice cloning.
# ref_audio_ /tmp/tmp8nado52s.wav
#
#
# No voice tag found, using main.
# Voice: main
# gen_text 0 This is a generated test sentence using the F5 TTS voice cloning model.
#
#
# Generating audio in 1 batches...
# ...

# %%
from IPython.display import Audio

Audio("/kaggle/working/output/generated_speech.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !f5-tts_infer-cli \
  --model F5TTS_Base \
  --ref_audio "/kaggle/input/datasets/sanikasathe20/stutter/sattu_patil.wav.wav" \
  --ref_text "electric vehicles are one that runs on electricity instead of petrola and disel .they use rechargeble batteries." \
  --gen_text "Electric vehicles are becoming more popular around the world today because they help reduce pollution." \
  --output_dir "/kaggle/working/output" \
  --output_file "natural_speech.wav" \
  --remove_silence
# Out:
# Download Vocos from huggingface charactr/vocos-mel-24khz
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Using F5TTS_Base...
#
# vocab :  /kaggle/working/F5-TTS/src/f5_tts/infer/examples/vocab.txt
# token :  custom
# model :  /root/.cache/huggingface/hub/models--SWivid--F5-TTS/snapshots/84e5a410d9cead4de2f847e7c9369a6440bdfaca/F5TTS_Base/model_1200000.safetensors
#
# Voice: main
# ref_audio  /kaggle/input/datasets/sanikasathe20/stutter/sattu_patil.wav.wav
# Converting audio...
# Audio is over 12s, clipping short. (3)
# Using custom reference text...
#
# ref_text   electric vehicles are one that runs on electricity instead of petrola and disel .they use rechargeble batteries.
# ref_audio_ /tmp/tmpuf42_1v6.wav
#
#
# No voice tag found, using main.
# Voice: main
# ...

# %%
from IPython.display import Audio

Audio("/kaggle/working/output/natural_speech.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !python -m f5_tts.infer.infer_gradio --share
# Out:
# Download Vocos from huggingface charactr/vocos-mel-24khz
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# F5TTS_v1_Base/model_1250000.safetensors: downloading bytes: ▎|  466MB, 38.8MB/s
# F5TTS_v1_Base/model_1250000.safetensors: downloading bytes: ▌|  724MB, 60.3MB/s
# F5TTS_v1_Base/model_1250000.safetensors: downloading bytes: ▌|  789MB, 65.7MB/s
# F5TTS_v1_Base/model_1250000.safetensors: downloading bytes: ▋|  861MB, 71.3MB/s
# F5TTS_v1_Base/model_1250000.safetensors: downloading bytes: ▋|  985MB, 82.2MB/s
# F5TTS_v1_Base/model_1250000.safetensors: downloading bytes: ▊| 1.05GB, 87.5MB/s
# F5TTS_v1_Base/model_1250000.safetensors: downloading bytes: ▉| 1.25GB,  106MB/s
# F5TTS_v1_Base/model_1250000.safetensors: reconstructing file:  80%|▊| 1.07GB / 1
# F5TTS_v1_Base/model_1250000.safetensors: downloading bytes: █| 1.28GB,  109MB/s
# ...

# %%
from IPython.display import HTML, display
import base64

recorder_html = """
<div style="padding: 10px; border: 1px solid #ccc; border-radius: 8px; width: 300px;">
  <button id="startBtn" onclick="startRecording()" style="padding: 8px 12px; margin-right: 5px;">🎙️ Start Recording</button>
  <button id="stopBtn" onclick="stopRecording()" disabled style="padding: 8px 12px;">🛑 Stop & Save</button>
  <audio id="audioPreview" controls style="display:none; margin-top: 10px; width: 100%;"></audio>
</div>

<script>
let mediaRecorder;
let audioChunks = [];

async function startRecording() {
    let stream = await navigator.mediaDevices.getUserMedia({ audio: true });
    mediaRecorder = new MediaRecorder(stream);
    audioChunks = [];
    mediaRecorder.ondataavailable = event => audioChunks.push(event.data);
    mediaRecorder.onstop = async () => {
        let audioBlob = new Blob(audioChunks, { type: 'audio/wav' });
        let reader = new FileReader();
        reader.readAsDataURL(audioBlob);
        reader.onloadend = () => {
            let base64Data = reader.result.split(',')[1];
            IPython.notebook.kernel.execute(`live_audio_base64 = "${base64Data}"`);
        };
        document.getElementById('audioPreview').src = URL.createObjectURL(audioBlob);
        document.getElementById('audioPreview').style.display = 'block';
    };
    mediaRecorder.start();
    document.getElementById('startBtn').disabled = true;
    document.getElementById('stopBtn').disabled = false;
}

function stopRecording() {
    mediaRecorder.stop();
    document.getElementById('startBtn').disabled = false;
    document.getElementById('stopBtn').disabled = true;
}
</script>
"""

display(HTML(recorder_html))
# Out:
# <div style="padding: 10px; border: 1px solid #ccc; border-radius: 8px; width: 300px;">
#   <button id="startBtn" onclick="startRecording()" style="padding: 8px 12px; margin-right: 5px;">🎙️ Start Recording</button>
#   <button id="stopBtn" onclick="stopRecording()" disabled style="padding: 8px 12px;">🛑 Stop & Save</button>
#   <audio id="audioPreview" controls style="display:none; margin-top: 10px; width: 100%;"></audio>
# </div>
#
# <script>
# let mediaRecorder;
# let audioChunks = [];
#
# async function startRecording() {
#     let stream = await navigator.mediaDevices.getUserMedia({ audio: true });
#     mediaRecorder = new MediaRecorder(stream);
#     audioChunks = [];
#     mediaRecorder.ondataavailable = event => audioChunks.push(event.data);
#     mediaRecorder.onstop = async () => {
#         let audioBlob = new Blob(audioChunks, { type: 'audio/wav' });
#         let reader = new FileReader();
#         reader.readAsDataURL(audioBlob);
#         reader.onloadend = () => {
# ...

# %%
import base64

with open("/kaggle/working/my_live_voice.wav", "wb") as f:
    f.write(base64.b64decode(live_audio_base64))

print("Saved your voice to /kaggle/working/my_live_voice.wav!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_58/1863640326.py in <cell line: 0>()
#       2
#       3 with open("/kaggle/working/my_live_voice.wav", "wb") as f:
# ----> 4     f.write(base64.b64decode(live_audio_base64))
#       5
#       6 print("Saved your voice to /kaggle/working/my_live_voice.wav!")
#
# NameError: name 'live_audio_base64' is not defined

# %%
# !f5-tts_infer-cli \
  --model F5TTS_Base \
  --ref_audio "/kaggle/working/my_live_voice.wav" \
  --ref_text "Type the EXACT words you just spoke into the microphone here" \
  --gen_text "This is generated speech cloned from my live microphone recording." \
  --output_dir "/kaggle/working/output" \
  --output_file "live_voice_output.wav" \
  --remove_silence

# %%
from IPython.display import Audio

Audio("/kaggle/working/output/live_voice_output.wav")

# %%
import gradio as gr
from f5_tts.infer.infer_gradio import app

# Enable queuing to prevent 504 Gateway Timeouts over public links
app.queue(default_concurrency_limit=2)
app.launch(share=True, show_error=True)

# %%
# !python -m f5_tts.infer.infer_gradio --share
# Out:
# Download Vocos from huggingface charactr/vocos-mel-24khz
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# vocab :  /kaggle/working/F5-TTS/src/f5_tts/infer/examples/vocab.txt
# token :  custom
# model :  /root/.cache/huggingface/hub/models--SWivid--F5-TTS/snapshots/84e5a410d9cead4de2f847e7c9369a6440bdfaca/F5TTS_v1_Base/model_1250000.safetensors
#
# Starting app...
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://5c9e2e8f59eedfb937.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)

# %%
# !f5-tts_infer-gradio --share

# %% [markdown]
# ## Serve F5-TTS as an API for the Steamroller app
# Run the three cells below (after the setup cells above have already run once) to expose this notebook as an HTTP endpoint your local Streamlit app can call.

# %%
# !pip install -q flask pyngrok

# %%
import os
import uuid
import subprocess
from flask import Flask, request, send_file

app = Flask(__name__)

WORKDIR = "/kaggle/working"
UPLOAD_DIR = os.path.join(WORKDIR, "uploads")
OUTPUT_DIR = os.path.join(WORKDIR, "output")
os.makedirs(UPLOAD_DIR, exist_ok=True)
os.makedirs(OUTPUT_DIR, exist_ok=True)


@app.route("/health", methods=["GET"])
def health():
    return {"status": "ok"}


@app.route("/clone", methods=["POST"])
def clone():
    text = request.form.get("text")
    ref_text = request.form.get("ref_text", "")
    speaker_file = request.files.get("speaker_wav")

    if not text or not speaker_file:
        return {"error": "text and speaker_wav are required"}, 400

    uid = uuid.uuid4().hex
    ref_path = os.path.join(UPLOAD_DIR, f"ref_{uid}.wav")
    speaker_file.save(ref_path)

    output_filename = f"clone_{uid}.wav"

    cmd = [
        "f5-tts_infer-cli",
        "--model", "F5TTS_Base",
        "--ref_audio", ref_path,
        "--ref_text", ref_text,
        "--gen_text", text,
        "--output_dir", OUTPUT_DIR,
        "--output_file", output_filename,
        "--remove_silence",
    ]

    result = subprocess.run(cmd, capture_output=True, text=True)

    if result.returncode != 0:
        return {"error": result.stderr[-2000:]}, 500

    output_path = os.path.join(OUTPUT_DIR, output_filename)
    if not os.path.exists(output_path):
        return {"error": "F5-TTS ran but no output file was produced", "log": result.stdout[-2000:]}, 500

    return send_file(output_path, mimetype="audio/wav")

# %%
from pyngrok import ngrok

ngrok.set_auth_token("YOUR_NGROK_AUTHTOKEN")  # get a free token at https://ngrok.com
public_url = ngrok.connect(5000)
print("Public URL:", public_url)
print("Copy this into the KAGGLE_TTS_URL environment variable on your local machine.")

app.run(port=5000)
